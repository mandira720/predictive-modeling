# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics,model_selection
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix

# %%
data=pd.read_csv("Holiday_Package.csv")

# %%
data.head(40)
# Out:
#     Unnamed: 0 Holliday_Package  Salary  age  educ  no_young_children  \
# 0            1               no   48412   30     8                  1
# 1            2              yes   37207   45     8                  0
# 2            3               no   58022   46     9                  0
# 3            4               no   66503   31    11                  2
# 4            5               no   66734   44    12                  0
# 5            6              yes   61590   42    12                  0
# 6            7               no   94344   51     8                  0
# 7            8              yes   35987   32     8                  0
# 8            9               no   41140   39    12                  0
# 9           10               no   35826   43    11                  0
# 10          11               no   42643   45    11                  0
# 11          12               no   35157   60    12                  0
# ...

# %%
data.no_young_children.unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %%
data.isnull().any()
# Out:
# Unnamed: 0           False
# Holliday_Package     False
# Salary               False
# age                  False
# educ                 False
# no_young_children    False
# no_older_children    False
# foreign              False
# dtype: bool

# %%
data.duplicated().any()
# Out:
# False

# %%
data=data.drop("Unnamed: 0",axis=1)

# %%
#we are doing one hot encoding for holiday package and foreign
data=pd.get_dummies(data,columns=["Holliday_Package","foreign"])

# %%
data=data.drop(columns=['Holliday_Package_no','foreign_no'])

# %%
data.describe()
# Out:
#               Salary         age        educ  no_young_children  \
# count     872.000000  872.000000  872.000000         872.000000
# mean    47729.172018   39.955275    9.307339           0.311927
# std     23418.668531   10.551675    3.036259           0.612870
# min      1322.000000   20.000000    1.000000           0.000000
# 25%     35324.000000   32.000000    8.000000           0.000000
# 50%     41903.500000   39.000000    9.000000           0.000000
# 75%     53469.500000   48.000000   12.000000           0.000000
# max    236961.000000   62.000000   21.000000           3.000000
#
#        no_older_children  Holliday_Package_yes  foreign_yes
# count         872.000000            872.000000   872.000000
# mean            0.982798              0.459862     0.247706
# std             1.086786              0.498672     0.431928
# min             0.000000              0.000000     0.000000
# 25%             0.000000              0.000000     0.000000
# ...

# %%
data
# Out:
#      Salary  age  educ  no_young_children  no_older_children  \
# 0     48412   30     8                  1                  1
# 1     37207   45     8                  0                  1
# 2     58022   46     9                  0                  0
# 3     66503   31    11                  2                  0
# 4     66734   44    12                  0                  2
# ..      ...  ...   ...                ...                ...
# 867   40030   24     4                  2                  1
# 868   32137   48     8                  0                  0
# 869   25178   24     6                  2                  0
# 870   55958   41    10                  0                  1
# 871   74659   51    10                  0                  0
#
#      Holliday_Package_yes  foreign_yes
# 0                       0            0
# 1                       1            0
# 2                       0            0
# 3                       0            0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Salary                872 non-null    int64
#  1   age                   872 non-null    int64
#  2   educ                  872 non-null    int64
#  3   no_young_children     872 non-null    int64
#  4   no_older_children     872 non-null    int64
#  5   Holliday_Package_yes  872 non-null    uint8
#  6   foreign_yes           872 non-null    uint8
# dtypes: int64(5), uint8(2)
# memory usage: 35.9 KB

# %%
data['Holliday_Package_yes']=data['Holliday_Package_yes'].astype('int')
data['foreign_yes']=data['foreign_yes'].astype('int')

# %%
data.hist(figsize=(20,10))
plt.savefig('1.jpg')

# %%
sns.boxplot(x='Salary',data=data,palette='YlGn')
plt.savefig('2.jpg')

# %%
sns.boxplot(x='age',data=data,palette='YlGnBu')
plt.savefig('3.jpg')

# %%
sns.boxplot(x='educ',data=data,palette='OrRd')
plt.savefig('4.jpg')

# %%
sns.countplot(x='no_young_children',data=data,palette='twilight')
plt.savefig('5.jpg')

# %%
sns.countplot(x='no_older_children',data=data,palette='twilight_r')
plt.savefig('6.jpg')

# %%
sns.countplot(x='Holliday_Package_yes',data=data,palette='PuRd')
plt.savefig('7.jpg')

# %%
sns.countplot(x='foreign_yes',data=data,palette='Purples')
plt.savefig('8.jpg')

# %%
sns.lmplot(y='Salary',x='educ',data=data,hue='Holliday_Package_yes')
plt.savefig('9.jpg')

# %%
sns.lmplot(y='Salary',x='age',data=data,hue='Holliday_Package_yes')
plt.savefig('10.jpg')

# %%
sns.lmplot(y='age',x='educ',data=data,hue='Holliday_Package_yes')
plt.savefig('11.jpg')

# %%
sns.boxplot(x='Holliday_Package_yes',y='age',data=data,palette='Oranges')
plt.savefig('12.jpg')

# %%
sns.boxplot(x='Holliday_Package_yes',y='educ',data=data,palette='GnBu')
plt.savefig('13.jpg')

# %%
sns.pairplot(data)
plt.savefig('14.jpg')

# %%
cor=data.corr()
sns.heatmap(cor , annot=True)
plt.savefig('15.jpg')

# %%
df=data

# %%
x=df.drop('Holliday_Package_yes',axis=1)
y=df.pop('Holliday_Package_yes')

# %%
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(x,y,test_size=0.30,random_state=1,stratify = y)

# %%
ld=LinearDiscriminantAnalysis()
model=ld.fit(X_train,Y_train)

# %%
pred_class_train = model.predict(X_train)
pred_class_test = model.predict(X_test)

# %%
print('Confusion Matrix','\n',metrics.confusion_matrix(Y_train,pred_class_train),'\n')
print('Classification Report','\n',metrics.classification_report(Y_train, pred_class_train))
print('Confusion Matrix','\n',metrics.confusion_matrix(Y_test,pred_class_test),'\n')
print('Classification Report','\n',metrics.classification_report(Y_test, pred_class_test))
# Out:
# Confusion Matrix
#  [[243  86]
#  [119 162]]
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.67      0.74      0.70       329
#            1       0.65      0.58      0.61       281
#
#     accuracy                           0.66       610
#    macro avg       0.66      0.66      0.66       610
# weighted avg       0.66      0.66      0.66       610
#
# Confusion Matrix
#  [[109  33]
#  [ 61  59]]
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.64      0.77      0.70       142
#            1       0.64      0.49      0.56       120
#
#     accuracy                           0.64       262
#    macro avg       0.64      0.63      0.63       262
# weighted avg       0.64      0.64      0.63       262

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(Y_train,pred_class_train)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(Y_test,pred_class_test)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
# predict probabilities
probs = model.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(Y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(Y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.733

# %%
# predict probabilities
probs = model.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
test_auc = roc_auc_score(Y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(Y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.733

# %%
lmodel = LogisticRegression(solver='liblinear',max_iter=10000,penalty='l1',verbose=True,n_jobs=2 ,random_state=1)
lmodel.fit(X_train, Y_train)
# Out:
# [LibLinear]
# C:\Users\Mandira\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1353: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn("'n_jobs' > 1 does not have any effect when"
# LogisticRegression(max_iter=10000, n_jobs=2, penalty='l1', random_state=1,
#                    solver='liblinear', verbose=True)

# %%
model_score = lmodel.score(X_test, Y_test)
print('Accuracy Score is ',model_score)
# Out:
# Accuracy Score is  0.6603053435114504

# %%
pred_class_train = lmodel.predict(X_train)
pred_class_test = lmodel.predict(X_test)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(Y_train,pred_class_train)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(Y_test,pred_class_test)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report','\n',metrics.classification_report(Y_train, pred_class_train))
plot_confusion_matrix(lmodel,X_train,Y_train)
print('Classification Report','\n',metrics.classification_report(Y_test, pred_class_test))
plot_confusion_matrix(lmodel,X_test,Y_test)
# Out:
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71       329
#            1       0.66      0.57      0.61       281
#
#     accuracy                           0.67       610
#    macro avg       0.66      0.66      0.66       610
# weighted avg       0.66      0.67      0.66       610
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.66      0.77      0.71       142
#            1       0.66      0.53      0.59       120
#
#     accuracy                           0.66       262
#    macro avg       0.66      0.65      0.65       262
# weighted avg       0.66      0.66      0.65       262

# %%
# predict probabilities
probs = lmodel.predict_proba(X_train)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(Y_train, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(Y_train, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC: 0.735

# %%
# predict probabilities
probs = lmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
test_auc = roc_auc_score(Y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(Y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC: 0.735
